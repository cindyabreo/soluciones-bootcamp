# %% [markdown]
# # Hypothesis testing problem

# %% [markdown]
# ### **Exercise 1**
#
# #### ANOVA
#
# Suppose that a study wants to check if there is a significant difference between the goal averages of soccer players depending on the position in which they play. In case there is a difference, you want to know which positions differ from the rest.
#
# NOTE: You must replace the values <<<FIXME>>>.
#
# **Exercise: Load data from "datos_laliga.csv". It contains a sample of randomly selected players.**

# %%
import pandas as pd
datos = pd.read_csv("datos_laliga.csv")
datos
# Out:
#     id_player position  average
# 0      id_189       DC    0.310
# 1       id_85       DC    0.306
# 2      id_105       DC    0.320
# 3       id_34       DC    0.329
# 4       id_32       DC    0.369
# ..        ...      ...      ...
# 322    id_231       DC    0.381
# 323     id_20       MP    0.310
# 324    id_294       DC    0.340
# 325    id_218       DC    0.305
# 326    id_110       DC    0.288
#
# [327 rows x 3 columns]

# %%
datos.describe()
# Out:
#           average
# count  327.000000
# mean     0.332159
# std      0.035702
# min      0.174000
# 25%      0.309000
# 50%      0.331000
# 75%      0.354500
# max      0.437000

# %%
datos.hist(column="average")
# Out:
# array([[<AxesSubplot:title={'center':'average'}>]], dtype=object)

# %%
datos.hist(column="average", by="position")
# Out:
# array([[<AxesSubplot:title={'center':'DC'}>,
#         <AxesSubplot:title={'center':'MO'}>],
#        [<AxesSubplot:title={'center':'MP'}>,
#         <AxesSubplot:title={'center':'P'}>]], dtype=object)

# %%
datos.position.value_counts()
# Out:
# DC    154
# MP    120
# P      39
# MO     14
# Name: position, dtype: int64

# %%
datos.boxplot(column="average")
# Out:
# <AxesSubplot:>

# %%
datos.boxplot(column="average", by="position")
# Out:
# <AxesSubplot:title={'center':'average'}, xlabel='position'>

# %% [markdown]
# **Exercise: Identify the number of groups and number of observations per group to determine if it is a balanced model. The mean and standard deviation of the group are also calculated.**

# %%
#pd.crosstab(datos,columns=["DC", "MO", "MP", "P"])
pd.crosstab(datos['position'],columns="average")

#DC: Delantero centro
#MO: Medio ofensivo
#MP: Media punta
#P: Puntero
# Out:
# col_0     average
# position
# DC            154
# MO             14
# MP            120
# P              39

# %%
pd.crosstab(datos['position'],columns="position")
# Out:
# col_0     position
# position
# DC             154
# MO              14
# MP             120
# P               39

# %% [markdown]
# **Exercise: Calculate the mean and standar deviation by position**

# %%
datos.groupby('position')['average'].agg('mean')
# Out:
# position
# DC    0.331526
# MO    0.347786
# MP    0.334250
# P     0.322615
# Name: average, dtype: float64

# %% [markdown]
# **Exercise: Calculate the standard deviation by position**

# %%
datos.groupby('position')['average'].agg('std')
# Out:
# position
# DC    0.037095
# MO    0.036037
# MP    0.029444
# P     0.045132
# Name: average, dtype: float64

# %% [markdown]
# Since the number of observations per group is not constant, it is an unbalanced model. It is important to take this into account when checking the conditions of normality and homoscedasticity (s1 = s2 = s3 = s4). The most useful graphical representation before performing an ANOVA is the Box-Plot model.
#
# **Exercise: Plot a boxplot for each position**

# %%
#pip install plotnine

# %%
from plotnine import ggplot, aes, geom_boxplot, theme_bw
(
ggplot(datos) # What data to use
+ aes(x="position", y="average") # What variable to use
+ geom_boxplot() # Geometric object to use for drawing
+ theme_bw()
)
# Out:
# <ggplot: (115724176029)>

# %% [markdown]
# #### Independence
#
# The total sample size is <10% of the population of all players in the league. The groups (categorical variable) are independent of each other since a random sample of players from the entire league (not just from the same team) has been made.
#
# Normal distribution of observations: The quantitative variable must be distributed in a normal way in each of the groups. The normality study can be done graphically (qqplot) or with a hypothesis test.
#
# **Exercise: Make an analysis about normal distribution for each position**

# %%
import numpy as np 
import pylab 
import matplotlib.pyplot as plt
import scipy.stats as stats

measurements = datos.loc[datos["position"] == "P","average"]
stats.probplot(measurements, dist="norm", plot=pylab)
plt.title("P")
plt.show()

measurements = datos.loc[datos["position"] == "MO","average"]
stats.probplot(measurements, dist="norm", plot=pylab)
plt.title("MO")
plt.show()

measurements = datos.loc[datos["position"] == "DC","average"]
stats.probplot(measurements, dist="norm", plot=pylab)
plt.title("DC")
plt.show()

measurements = datos.loc[datos["position"] == "MP","average"]
stats.probplot(measurements, dist="norm", plot=pylab)
plt.title("MP")
plt.show()

# %% [markdown]
# **Exercise: make the boxplot for each position, what you can say about them?**

# %%
#pip install plotly

# %%
from matplotlib.pyplot import plot

# %%
#pip install jupyterlab

# %%
import jupyterlab

# %%
# Using plotly
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Box(y=datos.loc[datos["position"] == "P","average"]))
fig.add_trace(go.Box(y=datos.loc[datos["position"] == "MO","average"]))
fig.add_trace(go.Box(y=datos.loc[datos["position"] == "DC","average"]))
fig.add_trace(go.Box(y=datos.loc[datos["position"] == "MP","average"]))
fig.show()

# %% [markdown]
# **Exercise: Use the Kolmogorov-Smirnov test or with or without the Lilliefors correction in order to know the normality distribution.**

# %%
datos.head()
# Out:
#   id_player position  average
# 0    id_189       DC    0.310
# 1     id_85       DC    0.306
# 2    id_105       DC    0.320
# 3     id_34       DC    0.329
# 4     id_32       DC    0.369

# %%
# Beginner way to do it

from statsmodels.stats.diagnostic import lilliefors
import numpy as np 

my_df = pd.DataFrame(index=np.arange(len(np.unique(datos["position"]))), columns=["position", "D_statistic", "p_value"])
my_df.head()
# Out:
#   position D_statistic p_value
# 0      NaN         NaN     NaN
# 1      NaN         NaN     NaN
# 2      NaN         NaN     NaN
# 3      NaN         NaN     NaN

# %%
my_df["position"] = np.unique(datos["position"])

for position in my_df["position"]:
    datos_subset = datos.loc[datos["position"] == position,:]
    D_statistic, p_value = lilliefors(datos_subset.average)
    my_df.loc[my_df["position"]==position,["D_statistic", "p_value"]] = D_statistic, p_value
    
print(my_df)
# Out:
#   position D_statistic   p_value
# 0       DC    0.070653  0.084495
# 1       MO    0.112049  0.903567
# 2       MP    0.044082  0.855077
# 3        P    0.087208  0.634941

# %%
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   position     4 non-null      object
#  1   D_statistic  4 non-null      object
#  2   p_value      4 non-null      object
# dtypes: object(3)
# memory usage: 128.0+ bytes

# %%
#Another way to do it (Highly recommendable)
#my_data.groupby("<<<FIXME>>>")["average"].apply(average)
datos.groupby('position')['average'].apply('mean')
# Out:
# position
# DC    0.331526
# MO    0.347786
# MP    0.334250
# P     0.322615
# Name: average, dtype: float64

# %% [markdown]
# The hypothesis tests do not show evidence of a lack of normality.
#
# Constant variance between groups (homoscedasticity):
#
# Given that there is a group (DC) that is at the limit to accept that it is distributed in a normal way, the Fisher and Bartlett tests are not recommended. Instead it is better to use a test based on the median Levene test or the Fligner-Killeen test.
#
# **Exercise: use the fligner and levene functions from scipy.stats in order to know the homocedasticy**

# %%
from scipy import stats

values_array = pd.DataFrame(datos.groupby('position')['average']).to_numpy()

print(stats.fligner(values_array[0,1], values_array[1,1], values_array[2,1], values_array[3,1]))

print(stats.levene(values_array[0,1], values_array[1,1], values_array[2,1], values_array[3,1]))

# stats.fligner(values_array[:,1]) # It doesn't work, please analyse
# Out:
# FlignerResult(statistic=6.97244018401731, pvalue=0.07278140457833458)
# LeveneResult(statistic=2.6056585191080566, pvalue=0.051799415350941756)

# %% [markdown]
# There is no significant evidence of lack of homoscedasticity in either of the two tests.
#
# The study of the conditions can be carried out after calculating the ANOVA, since if they are not fulfilled, it does not make much sense to continue. However, the most appropriate way to verify that the necessary conditions are satisfied is by studying the model residuals once the ANOVA has been generated.
#
# **Exercise: make an ANOVA table and analyze the p-value using the packages statsmodels and the bioinfokit**

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 327 entries, 0 to 326
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id_player  327 non-null    object
#  1   position   327 non-null    object
#  2   average    327 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 7.8+ KB

# %%
# get ANOVA table as R like output
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Ordinary Least Squares (OLS) model
model = ols('average ~ position', data=datos).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#             sum_sq     df         F    PR(>F)
# position  0.007557    3.0  1.994349  0.114693
# Residual  0.407984  323.0       NaN       NaN

# %%
#pip install bioinfokit
# Out:
# Collecting bioinfokitNote: you may need to restart the kernel to use updated packages.
#   WARNING: The script tabulate.exe is installed in 'C:\Users\cindy\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\cindy\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.
#   Downloading bioinfokit-2.0.8.tar.gz (84 kB)
#      ---------------------------------------- 84.6/84.6 KB 1.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas in c:\users\cindy\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from bioinfokit) (1.4.2)
# Requirement already satisfied: numpy in c:\users\cindy\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from bioinfokit) (1.22.4)
# Requirement already satisfied: matplotlib in c:\users\cindy\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from bioinfokit) (3.5.2)
# Requirement already satisfied: scipy in c:\users\cindy\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from bioinfokit) (1.8.1)
# Requirement already satisfied: scikit-learn in c:\users\cindy\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from bioinfokit) (1.1.1)
# Requirement already satisfied: seaborn in c:\users\cindy\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from bioinfokit) (0.11.2)
# Collecting matplotlib-venn
#   Downloading matplotlib-venn-0.11.7.tar.gz (29 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting tabulate
#   Downloading tabulate-0.8.10-py3-none-any.whl (29 kB)
# Requirement already satisfied: statsmodels in c:\users\cindy\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from bioinfokit) (0.13.2)
# Collecting textwrap3
#   Downloading textwrap3-0.9.2-py2.py3-none-any.whl (12 kB)
# Collecting adjustText
#   Downloading adjustText-0.7.3.tar.gz (7.5 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\cindy\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->bioinfokit) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cindy\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->bioinfokit) (4.33.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\cindy\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->bioinfokit) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\cindy\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->bioinfokit) (9.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\cindy\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->bioinfokit) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\cindy\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->bioinfokit) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\cindy\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib->bioinfokit) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cindy\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas->bioinfokit) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\cindy\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from scikit-learn->bioinfokit) (3.1.0)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\cindy\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from scikit-learn->bioinfokit) (1.1.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\cindy\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from statsmodels->bioinfokit) (0.5.2)
# Requirement already satisfied: six in c:\users\cindy\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from patsy>=0.5.2->statsmodels->bioinfokit) (1.16.0)
# Using legacy 'setup.py install' for bioinfokit, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for adjustText, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for matplotlib-venn, since package 'wheel' is not installed.
# Installing collected packages: textwrap3, tabulate, matplotlib-venn, adjustText, bioinfokit
#   Running setup.py install for matplotlib-venn: started
#   Running setup.py install for matplotlib-venn: finished with status 'done'
#   Running setup.py install for adjustText: started
#   Running setup.py install for adjustText: finished with status 'done'
#   Running setup.py install for bioinfokit: started
#   Running setup.py install for bioinfokit: finished with status 'done'
# Successfully installed adjustText-0.7.3 bioinfokit-2.0.8 matplotlib-venn-0.11.7 tabulate-0.8.10 textwrap3-0.9.2

# %%
# ANOVA with package bioinfokit
from bioinfokit.analys import stat
res = stat()
res.anova_stat(df=datos, res_var='value', anova_model=' average ~ position')
res.anova_summary
# output (ANOVA F and p value)
# Out:
#              df    sum_sq   mean_sq         F    PR(>F)
# position    3.0  0.007557  0.002519  1.994349  0.114693
# Residual  323.0  0.407984  0.001263       NaN       NaN

# %% [markdown]
# **Exercise: make a plot of the fitted values vs residuals. Make the plot of the Standardized Residuals. Make the histogram of the residuals.**

# %%
# QQ-plot
import statsmodels.api as sm
import matplotlib.pyplot as plt

#plt.scatter(res.anova_model_out.<<<FIXME>>>, res.anova_model_out.<<<FIXME>>>)
plt.scatter(res.anova_model_out.resid, res.anova_model_out.resid)
plt.xlabel("Fitted values")
plt.ylabel("Residuals")
plt.title("Residuals vs. Fitted")
plt.show()

# %%
# res.anova_std_residuals are standardized residuals obtained from ANOVA (check above)
sm.qqplot(res.anova_std_residuals, line='45')
plt.xlabel("Theoretical Quantiles")
plt.ylabel("Standardized Residuals")
plt.show()

# %%
# histogram
plt.hist(res.anova_model_out.resid, bins='auto', histtype='bar', ec='k') 
plt.xlabel("Residuals")
plt.ylabel('Frequency')
plt.show()

# %%
# res.anova_std_residuals are standardized residuals obtained from ANOVA (check above)
sm.qqplot(res.anova_std_residuals, line='45')
plt.xlabel("Theoretical Quantiles")
plt.ylabel("Standardized Residuals")
plt.show()

# histogram
plt.hist(res.anova_model_out.resid, bins='auto', histtype='bar', ec='k') 
plt.xlabel("Residuals")
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Given that the p-value is higher than 0.05, there is not enough evidence to consider that at least two means are different. The graphical representation of the residuals does not show lack of homoscedasticity (graph 1) and in the qqplot the residuals are distributed very close to the normal line (graph 2 and 3).

# %% [markdown]
# ### **Exercise 2**
#
# #### T-TEST INDEPENDENT
#
# A professor gives online lectures. Later, he uploads recorded lectures to the cloud for students who followed the course asynchronously (those who did not attend the lesson but later watched the records). However, he believes that the students who attend class at the class time and participate in the process are more successful. Therefore, he recorded the average grades of the students at the end of the semester. The data is below.
#
# ```py
# synchronous = [94. , 84.9, 82.6, 69.5, 80.1, 79.6, 81.4, 77.8, 81.7, 78.8, 73.2, 87.9, 87.9, 93.5, 82.3, 79.3, 78.3, 71.6, 88.6, 74.6, 74.1, 80.6]
#
#
# asynchronous = [77.1, 71.7, 91. , 72.2, 74.8, 85.1, 67.6, 69.9, 75.3, 71.7, 65.7, 72.6, 71.5, 78.2]
# ```
#
# Conduct the hypothesis testing to check whether the professor’s belief is statistically significant by using a 0.05 significance level to evaluate the null and alternative hypotheses. Before doing hypothesis testing, check the related assumptions. Comment on the results.

# %% [markdown]
# **1. Defining Hypothesis**
#
# H₀: μₛ≤μₐ
#
# H₁: μₛ>μₐ

# %% [markdown]
# **2. Assumption Check**
#
# H₀: The data is normally distributed.
#
# H₁: The data is not normally distributed.
#
# Assume that α=0.05. If the p-value is >0.05, it can be said that data is normally distributed.

# %%
# import libraries

# %%
def check_normality(data):
    test_stat_normality, p_value_normality=stats.shapiro(data)
    print("p value:%.4f" % p_value_normality)
    if p_value_normality <0.05:
        print("Reject null hypothesis >> The data is not normally distributed")
    else:
        print("Fail to reject null hypothesis >> The data is normally distributed")

# %%
#define veriables

# %%
#check normality

# %% [markdown]
# H₀: The variances of the samples are the same.
#
# H₁: The variances of the samples are different.

# %%
def check_variance_homogeneity(group1, group2):
    test_stat_var, p_value_var= stats.levene(group1,group2)
    print("p value:%.4f" % p_value_var)
    if p_value_var <0.05:
        print("Reject null hypothesis >> The variances of the samples are different.")
    else:
        print("Fail to reject null hypothesis >> The variances of the samples are same.")

# %% [markdown]
# It tests the null hypothesis that the population variances are equal (called homogeneity of variance or homoscedasticity). Suppose the resulting p-value of Levene’s test is less than the significance level (typically 0.05). In that case, the obtained differences in sample variances are unlikely to have occurred based on random sampling from a population with equal variances.

# %%
#check_variance_homogeneity

# %% [markdown]
# Are assumptions satisfied?

# %%
#perform the parametric version of the test for 2 groups and unpaired data.

# %% [markdown]
# Macke a conclusion
